180: 社会·美食·旅行-纪录片

182: 影视杂谈-影视

183: 影视剪辑-影视

184: 预告 资讯-影视

185: 国产剧-电视剧

187: 海外剧-电视剧

189: 电脑装机-数码

190: 摄影摄像-数码

191: 影音智能-数码

192: 风尚标-时尚

193: MV-音乐

194: 电音-音乐

195: 动态漫·广播剧-国创"""

# %%
table = table.split('\n')
table
# Out:
# ['',
#  '12: 未知(隐藏)-未知',
#  '',
#  '15: 连载剧集(隐藏)-电视剧',
#  '',
#  '16: flash游戏(隐藏)-游戏',
#  '',
#  '17: 单机游戏-游戏',
#  '',
#  '19: Mugen-游戏',
#  '',
#  '20: 宅舞-舞蹈',
#  '',
#  '21: 日常-生活',
#  '',
#  '22: 鬼畜调教-鬼畜',
#  '',
#  '24: MAD·AMV-动画',
#  '',
#  '25: MMD·3D-动画',
#  '',
#  '26: 音MAD-鬼畜',
#  '',
#  '27: 综合-动画',
#  '',
#  '28: 原创音乐-音乐',
#  '',
#  '29: 音乐现场-音乐',
#  '',
#  '30: VOCALOID·UTAU-音乐',
#  '',
#  '31: 翻唱-音乐',
#  '',
#  '32: 完结动画-番剧',
#  '',
#  '33: 连载动画-番剧',
#  '',
#  '37: 人文历史-纪录片',
#  '',
#  '39: 演讲· 公开课-科技',
#  '',
#  '41: 未知(隐藏)-未知',
#  '',
#  '43: 未知(隐藏)-未知',
#  '',
#  '46: MMD.3D(隐藏)-动画',
#  '',
#  '47: 短片·手书·配音-动画',
#  '',
#  '50: 短片·手书·配音(隐藏)-动画',
#  '',
#  '51: 资讯-番剧',
#  '',
#  '53: 综合(隐藏)-动画',
#  '',
#  '54: OP/ED/OST(隐藏)-音乐',
#  '',
#  '56: VOCALOID(隐藏)-音乐',
#  '',
#  '59: 演奏-音乐',
#  '',
#  '60: 电子竞技(隐藏)-游戏',
#  '',
#  '63: 未知(隐藏)-未知',
#  '',
#  '65: 网络游戏-游戏',
#  '',
#  '67: 单机游戏(隐藏)-游戏',
#  '',
#  '71: 综艺-娱乐',
#  '',
#  '74: 日常(隐藏)-生活',
#  '',
#  '75: 动物圈-生活',
# ...

# %%
while("" in table) : 
    table.remove("")
table
# Out:
# ['12: 未知(隐藏)-未知',
#  '15: 连载剧集(隐藏)-电视剧',
#  '16: flash游戏(隐藏)-游戏',
#  '17: 单机游戏-游戏',
#  '19: Mugen-游戏',
#  '20: 宅舞-舞蹈',
#  '21: 日常-生活',
#  '22: 鬼畜调教-鬼畜',
#  '24: MAD·AMV-动画',
#  '25: MMD·3D-动画',
#  '26: 音MAD-鬼畜',
#  '27: 综合-动画',
#  '28: 原创音乐-音乐',
#  '29: 音乐现场-音乐',
#  '30: VOCALOID·UTAU-音乐',
#  '31: 翻唱-音乐',
#  '32: 完结动画-番剧',
#  '33: 连载动画-番剧',
#  '37: 人文历史-纪录片',
#  '39: 演讲· 公开课-科技',
#  '41: 未知(隐藏)-未知',
#  '43: 未知(隐藏)-未知',
#  '46: MMD.3D(隐藏)-动画',
#  '47: 短片·手书·配音-动画',
#  '50: 短片·手书·配音(隐藏)-动画',
#  '51: 资讯-番剧',
#  '53: 综合(隐藏)-动画',
#  '54: OP/ED/OST(隐藏)-音乐',
#  '56: VOCALOID(隐藏)-音乐',
#  '59: 演奏-音乐',
#  '60: 电子竞技(隐藏)-游戏',
#  '63: 未知(隐藏)-未知',
#  '65: 网络游戏-游戏',
#  '67: 单机游戏(隐藏)-游戏',
#  '71: 综艺-娱乐',
#  '74: 日常(隐藏)-生活',
#  '75: 动物圈-生活',
#  '76: 美食圈-生活',
#  '77: 动物圈(隐藏)-生活',
#  '79: 动物圈(隐藏)-生活',
#  '80: 美食圈(隐藏)-生活',
#  '82: 电影相关(隐藏)-电影',
#  '83: 其他国家-电影',
#  '85: 短片-影视',
#  '86: 特摄-影视',
#  '94: 完结动画(隐藏)-动画',
#  '95: 手机平板-数码',
#  '96: 星海-科技',
#  '98: 机械-科技',
#  '114: 综艺(隐藏)-娱乐',
# ...

# %%
df_type= pd.DataFrame(columns=['typeid', 'typename','section','sub-section'])
for i in table:
    type_info = i.split(': ')
    type_info2=type_info[1].split('-')
    df_type = df_type.append({'typeid':type_info[0], 'typename':type_info[1],'section':type_info2[1],'sub-section':type_info2[0]}, ignore_index=True)
df_type
# Out:
#     typeid          typename section    sub-section
# 0       12         未知(隐藏)-未知      未知         未知(隐藏)
# 1       15      连载剧集(隐藏)-电视剧     电视剧       连载剧集(隐藏)
# 2       16    flash游戏(隐藏)-游戏      游戏    flash游戏(隐藏)
# 3       17           单机游戏-游戏      游戏           单机游戏
# 4       19          Mugen-游戏      游戏          Mugen
# 5       20             宅舞-舞蹈      舞蹈             宅舞
# 6       21             日常-生活      生活             日常
# 7       22           鬼畜调教-鬼畜      鬼畜           鬼畜调教
# 8       24        MAD·AMV-动画      动画        MAD·AMV
# 9       25         MMD·3D-动画      动画         MMD·3D
# 10      26           音MAD-鬼畜      鬼畜           音MAD
# 11      27             综合-动画      动画             综合
# 12      28           原创音乐-音乐      音乐           原创音乐
# 13      29           音乐现场-音乐      音乐           音乐现场
# 14      30  VOCALOID·UTAU-音乐      音乐  VOCALOID·UTAU
# 15      31             翻唱-音乐      音乐             翻唱
# 16      32           完结动画-番剧      番剧           完结动画
# ...

# %%
df_type.to_csv("typeid.csv")
