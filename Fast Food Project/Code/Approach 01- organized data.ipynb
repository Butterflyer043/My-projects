# %%
import pandas as pd
import numpy as np
import re
import string
import csv
df = pd.read_csv('all_item.csv')
df.insert(loc=3, column='Types', value=df['Category'])
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df.head()
# Out:
#    Unnamed: 0 Restaurant Category    Types   Items  Calories  Protein (g)  \
# 0           0    Popeyes  chicken  chicken    Wing       210           13
# 1           1    Popeyes  chicken  chicken     Leg       160           14
# 2           2    Popeyes  chicken  chicken   Thigh       280           14
# 3           3    Popeyes  chicken  chicken  Breast       440           35
# 4           4    Popeyes  chicken  chicken    Wing       210           13
#
#    Carbs (g)  Sodium (mg)  Sugars (g)
# 0          8        610.0         0.0
# 1          5        460.0         0.0
# 2          7        640.0         0.0
# 3         16       1330.0         0.0
# 4          8        410.0         1.0

# %%
#clean dataset delete unusual data
df.loc[df.Category.str.contains('chicken & morechicken'),'Category'] = 'chicken & more'  
df = df[~df.Items.str.contains('Sauce')]

a = list(range(1312,1326))+list(range(1219,1227))
for i in a:
    try:
        df = df.drop( i, axis=0)
    except:
        pass

# %%
df.Restaurant.unique()
# Out:
# array(['Popeyes', 'Mcdonalds', 'Burger-king', 'chick-fil-a',
#        'jack-in-the-box', 'Wendys', 'Subway', 'KFC', 'Arbys',
#        'dunkin-donuts', 'Papa-Johns', 'pizza-hut', 'Taco-Bell',
#        'panda-express', 'hardees', 'five-guys'], dtype=object)

# %%
df.Category.unique()
# Out:
# array(['chicken', 'sandwiches & wraps', 'seafood', 'sides', 'breakfast',
#        'desserts', 'beverages', 'burgers', 'chicken and sandwiches',
#        'salads', 'snacks & sides', 'mccafé', 'dessert & shakes',
#        'all day breakfast', 'happy meal – protein', 'happy meal – side',
#        'happy meal – drinks', 'mccafé® bakery', 'whopper® sandwiches',
#        'flame broiled burgerseval', 'chicken & more', 'king jr™ meals',
#        'salads & sides', 'coca cola classic®', 'diet coke®eval',
#        'sprite®', 'dr. pepper®', 'barq’s root beer®', 'cherry coke®',
#        'fanta® orange', 'hi-c® fruit punch',
#        'minute maid® light lemonade', 'sweet tea', 'unsweetened tea',
#        'capri sun® 100% apple juice', 'minute maid® orange juice',
#        'frozen coke® ', 'bk® café coffee', 'bk® café decaf coffee',
#        'bk® café iced vanilla coffee', 'bk® café iced mocha coffee',
#        'bk® café mocha frappe', 'bk® café caramel frappe', 'classics',
# ...

# %%
df.loc[df.Category.str.contains('dessert'),'Category'] = "dessert"
df.loc[df.Category.str.contains('side'),'Category'] = "sides"
df.loc[df.Category.str.contains('reference'),'Category']= "sides"
df.loc[df.Category.str.contains('turnovers'),'Category']= "sides"
df.loc[df.Category.str.contains('extras'),'Category']= "sides"
df.loc[df.Category.str.contains('vegetables'),'Category']= "sides"
df.loc[df.Category.str.contains('cookies'),'Category']= "sides"
df.loc[df.Category.str.contains('soup'),'Category']= "sides"
df.loc[df.Category.str.contains('john’s favorite'),'Category']= "sides"
df.loc[df.Category.str.contains('garden fresh'),'Category']= "sides"
df.loc[df.Category.str.contains('spicy italian'),'Category']= "sides"
df.loc[df.Category.str.contains('strips and filets'),'Category']= "sides"
df.loc[df.Category.str.contains('snacks'),'Category']= "sides"
df.loc[df.Category.str.contains('appetizer'),'Category']= "sides"
df.loc[df.Category.str.contains('salad'),'Category']= "sides"

# %%
df.loc[df.Category.str.contains('chicken'),'Category'] = "entrees"
df.loc[df.Category.str.match('seafood'),'Category'] = "entrees"
df.loc[df.Category.str.match('breakfast'),'Category'] = "entrees"

df.loc[df.Category.str.match('happy meal – protein'),'Category']= "entrees"
df.loc[df.Category.str.contains('sandwich'),'Category']= "entrees"
df.loc[df.Category.str.contains('burger'),'Category']= "entrees"
df.loc[df.Category.str.contains('meal'),'Category']= "entrees"
df.loc[df.Category.str.contains('breakfast'),'Category']= "entrees"
df.loc[df.Category.str.contains('dinner'),'Category']= "entrees"
df.loc[df.Category.str.contains('turkey'),'Category']= "entrees"
df.loc[df.Category.str.contains('fries'),'Category']= "entrees"
df.loc[df.Category.str.contains('flatbread'),'Category']= "entrees"
df.loc[df.Category.str.contains('pie'),'Category']= "entrees"
df.loc[df.Category.str.contains('pizza'),'Category']= "entrees"
df.loc[df.Category.str.contains('works'),'Category']= "entrees"
df.loc[df.Category.str.contains('dogs'),'Category']= "entrees"
df.loc[df.Category.str.contains('wings'),'Category']= "entrees"
df.loc[df.Category.str.contains('menu'),'Category']= "entrees"
df.loc[df.Category.str.contains('different'),'Category']= "entrees"
df.loc[df.Category.str.contains('bakery'),'Category']= "entrees"
df.loc[df.Category.str.contains('wrap'),'Category']= "entrees"
df.loc[df.Category.str.contains('muffins'),'Category']= "entrees"
df.loc[df.Category.str.contains('donuts'),'Category']= "entrees"
df.loc[df.Category.str.contains('bagel'),'Category']= "entrees"
df.loc[df.Category.str.contains('cheese'),'Category']= "entrees"
df.loc[df.Category.str.contains('danish'),'Category']= "entrees"
df.loc[df.Category.str.contains('pepperoni'),'Category']= "entrees"
df.loc[df.Category.str.contains('the meats'),'Category']= "entrees"
df.loc[df.Category.str.contains('spinach alfredo'),'Category']= "entrees"
df.loc[df.Category.str.contains('chalapus'),'Category']= "entrees"
df.loc[df.Category.str.contains('classics'),'Category']= "entrees"
df.loc[df.Category.str.contains('fresco'),'Category']= "entrees"
df.loc[df.Category.str.contains('baked'),'Category']= "entrees"
df.loc[df.Category.str.contains('why pay more'),'Category']= "entrees"
df.loc[df.Category.str.contains('beef'),'Category']= "entrees"
df.loc[df.Category.str.contains('shrimp'),'Category']= "entrees"
df.loc[df.Category.str.contains('gorditas'),'Category']= "entrees"
df.loc[df.Category.str.contains('toasted subs'),'Category']= "entrees"
df.loc[df.Category.str.contains('pastas'),'Category']= "entrees"
df.loc[df.Category.str.contains('healthy dining'),'Category']= "entrees"
df.loc[df.Category.str.contains('burritos'),'Category']= "entrees"
df.loc[df.Category.str.contains('concretes'),'Category']= "entrees"
df.loc[df.Category.str.contains('alternatives'),'Category']= "entrees"
df.loc[df.Category.str.contains('cantina bell'),'Category']= "entrees"
df.loc[df.Category.str.contains('veggies'),'Category']= "entrees"
df.loc[df.Category.str.contains('nachos'),'Category']= "entrees"
df.loc[df.Category.str.contains('specialties'),'Category']= "entrees"
df.loc[df.Category.str.contains('tacos'),'Category']= "entrees"
df.loc[df.Category.str.contains('other items'),'Category']= "entrees"
df.loc[df.Category.str.contains('might minis'),'Category']= "entrees"

# %%
df.loc[df.Category.str.contains('beverage'),'Category'] = "beverages"
df.loc[df.Category.str.contains('tea'),'Category'] = "beverages"
df.loc[df.Category.str.contains('coffee'),'Category'] = "beverages"
df.loc[df.Category.str.contains('coke'),'Category'] = "beverages"
df.loc[df.Category.str.contains('café'),'Category'] = "beverages"
df.loc[df.Category.str.contains('maid'),'Category'] = "beverages"
df.loc[df.Category.str.contains('drinks'),'Category'] = "beverages"
df.loc[df.Category.str.contains('coca'),'Category'] = "beverages"
df.loc[df.Category.str.contains('coolatta'),'Category'] = "beverages"
df.loc[df.Category.str.contains('smoothies'),'Category'] = "beverages"
df.loc[df.Category.str.contains('®'),'Category'] = "beverages"
df.loc[df.Category.str.contains('milkshakes'),'Category'] = "beverages"
df.loc[df.Category.str.contains('frosty'),'Category'] = "beverages"
df.loc[df.Category.str.contains('sundaes'),'Category'] = "beverages"
df.loc[df.Category.str.contains('cider'),'Category'] = "beverages"

# %%
rest_list = list(df.Restaurant.unique())
for i in rest_list:
    print(i)
    print(df[df.Restaurant==i].Category.unique())
# Out:
# Popeyes
# ['entrees' 'sides' 'dessert' 'beverages']
# Mcdonalds
# ['entrees' 'sides' 'beverages' 'dessert']
# Burger-king
# ['entrees' 'sides' 'dessert' 'beverages']
# chick-fil-a
# ['entrees' 'dessert' 'beverages' 'sides']
# jack-in-the-box
# ['entrees' 'sides' 'beverages' 'dessert']
# Wendys
# ['sides' 'beverages' 'entrees']
# Subway
# ['entrees' 'sides' 'beverages' 'dessert']
# KFC
# ['entrees' 'sides' 'dessert' 'beverages']
# Arbys
# ['sides' 'entrees' 'beverages' 'dessert']
# dunkin-donuts
# ['sides' 'entrees' 'beverages']
# Papa-Johns
# ['entrees' 'sides']
# pizza-hut
# ['entrees' 'sides' 'dessert' 'beverages']
# Taco-Bell
# ['beverages' 'entrees' 'sides']
# panda-express
# ['sides' 'entrees' 'beverages']
# hardees
# ['entrees' 'sides' 'dessert']
# five-guys
# ['entrees']

# %%
df.head()
# Out:
#    Unnamed: 0 Restaurant Category    Types   Items  Calories  Protein (g)  \
# 0           0    Popeyes  entrees  chicken    Wing       210           13
# 1           1    Popeyes  entrees  chicken     Leg       160           14
# 2           2    Popeyes  entrees  chicken   Thigh       280           14
# 3           3    Popeyes  entrees  chicken  Breast       440           35
# 4           4    Popeyes  entrees  chicken    Wing       210           13
#
#    Carbs (g)  Sodium (mg)  Sugars (g)
# 0          8        610.0         0.0
# 1          5        460.0         0.0
# 2          7        640.0         0.0
# 3         16       1330.0         0.0
# 4          8        410.0         1.0

# %%
df=df.drop("Unnamed: 0", axis=1) 
df.head()
# Out:
#   Restaurant Category    Types   Items  Calories  Protein (g)  Carbs (g)  \
# 0    Popeyes  entrees  chicken    Wing       210           13          8
# 1    Popeyes  entrees  chicken     Leg       160           14          5
# 2    Popeyes  entrees  chicken   Thigh       280           14          7
# 3    Popeyes  entrees  chicken  Breast       440           35         16
# 4    Popeyes  entrees  chicken    Wing       210           13          8
#
#    Sodium (mg)  Sugars (g)
# 0        610.0         0.0
# 1        460.0         0.0
# 2        640.0         0.0
# 3       1330.0         0.0
# 4        410.0         1.0

# %%
df.to_csv("apporach01-clean data.csv")
